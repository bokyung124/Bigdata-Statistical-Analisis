# %%
import pandas as pd

# %%
df1 = pd.read_csv('./combinedata/data1.csv')
df2 = pd.read_csv('./combinedata/data2.csv')
df3 = pd.read_csv('./combinedata/data3.csv')

# %%
display(df1)
# Out:
#          학번   이름
# 0   1X10137  *현정
# 1   1X10194  *민지
# 2   1X12805  *예원
# 3   1X15363  *소연
# 4   1X16434  *민지
# 5   2X10333  *의정
# 6   2X10855  *서린
# 7   2X11621  *민서
# 8   2X11852  *채형
# 9   2X12158  *연우
# 10  2X12726  *희진
# 11  2X12795  *수아
# 12  2X13544  *다정
# 13  2X13847  *예린
# 14  2X14094  *민영
# 15  2X14235  *정연
# 16  2X14559  *서현
# 17  2X14839  *은진
# 18  2X14844  *원선
# 19  2X14900  *승연
# 20  2X14904  *지빈
# 21  2X15682  *보경
# 22  2X16030  *시영
# 23  2X16437  *시현
# 24  2X16678  *민지

# %%
display(df2)
# Out:
#          학번   이름
# 0   2X14904  *지빈
# 1   2X13544  *다정
# 2   2X14844  *원선
# 3   2X15682  *보경
# 4   2X14559  *서현
# 5   1X15978  *승희
# 6   2X12342  *영은
# 7   2X12192  *예지
# 8   1X10418  *은서
# 9   1X16296  *진주
# 10  1X10833  *현민
# 11  2X13013  *주영
# 12  2X15028  *채현
# 13  2X10565  *민영
# 14  2X13592  *유빈
# 15  2X13686  *민지
# 16  2X12491  *윤서
# 17  2X16542  *하빈
# 18  2X11999  *윤아
# 19  2X13885  *유리

# %%
display(df3)
# Out:
#          학번        학과(전공)
# 0   2X16437        IT공학전공
# 1   1X16434        IT공학전공
# 2   2X14904        IT공학전공
# 3   1X10833          경영학부
# 4   2X11999          경영학부
# 5   1X15978  르꼬르동블루외식경영전공
# 6   2X15682     소프트웨어융합전공
# 7   1X10194     소프트웨어융합전공
# 8   2X10333       컴퓨터과학전공
# 9   2X15028          통계학과
# 10  2X13013          통계학과
# 11  2X13592          통계학과
# 12  1X16296          통계학과
# 13  1X10418          통계학과
# 14  2X12192          통계학과
# 15  2X12342          통계학과
# 16  2X13686          통계학과
# 17  2X12491          통계학과
# 18  2X14559          통계학과
# 19  2X16542          통계학과
# 20  2X10565          통계학과
# 21  2X14844          통계학과
# 22  1X12805          통계학과
# 23  2X13847          통계학과
# 24  2X14839          통계학과
# 25  2X11621          통계학과
# 26  2X14094          통계학과
# 27  2X16678          통계학과
# 28  2X10855          통계학과
# 29  2X12795          통계학과
# 30  2X13544          통계학과
# 31  2X14900          통계학과
# 32  2X14235          통계학과
# 33  2X11852          통계학과
# 34  1X10137          통계학과
# 35  2X12726          통계학과
# 36  1X15363          통계학과
# 37  2X12158          통계학과
# 38  2X16030          통계학과
# 39  2X13885          통계학과

# %% [markdown]
# ## Pandas DataFrame
# - side-by-side (axis = 1): merge or join
#     - join은 제거될 예정
# - side-by-side (axis = 0): concat or append
#     - append는 제거될 예정

# %%
# 위아래로 붙이기 (stacking)
df = pd.concat([df1, df2])
display(df)
# Out:
#          학번   이름
# 0   1X10137  *현정
# 1   1X10194  *민지
# 2   1X12805  *예원
# 3   1X15363  *소연
# 4   1X16434  *민지
# 5   2X10333  *의정
# 6   2X10855  *서린
# 7   2X11621  *민서
# 8   2X11852  *채형
# 9   2X12158  *연우
# 10  2X12726  *희진
# 11  2X12795  *수아
# 12  2X13544  *다정
# 13  2X13847  *예린
# 14  2X14094  *민영
# 15  2X14235  *정연
# 16  2X14559  *서현
# 17  2X14839  *은진
# 18  2X14844  *원선
# 19  2X14900  *승연
# 20  2X14904  *지빈
# 21  2X15682  *보경
# 22  2X16030  *시영
# 23  2X16437  *시현
# 24  2X16678  *민지
# 0   2X14904  *지빈
# 1   2X13544  *다정
# 2   2X14844  *원선
# 3   2X15682  *보경
# 4   2X14559  *서현
# 5   1X15978  *승희
# 6   2X12342  *영은
# 7   2X12192  *예지
# 8   1X10418  *은서
# 9   1X16296  *진주
# 10  1X10833  *현민
# 11  2X13013  *주영
# 12  2X15028  *채현
# 13  2X10565  *민영
# 14  2X13592  *유빈
# 15  2X13686  *민지
# 16  2X12491  *윤서
# 17  2X16542  *하빈
# 18  2X11999  *윤아
# 19  2X13885  *유리

# %%
# 위아래로 붙이기, index는 새로 편집
df = pd.concat([df1, df2], ignore_index = True)
display(df)
# Out:
#          학번   이름
# 0   1X10137  *현정
# 1   1X10194  *민지
# 2   1X12805  *예원
# 3   1X15363  *소연
# 4   1X16434  *민지
# 5   2X10333  *의정
# 6   2X10855  *서린
# 7   2X11621  *민서
# 8   2X11852  *채형
# 9   2X12158  *연우
# 10  2X12726  *희진
# 11  2X12795  *수아
# 12  2X13544  *다정
# 13  2X13847  *예린
# 14  2X14094  *민영
# 15  2X14235  *정연
# 16  2X14559  *서현
# 17  2X14839  *은진
# 18  2X14844  *원선
# 19  2X14900  *승연
# 20  2X14904  *지빈
# 21  2X15682  *보경
# 22  2X16030  *시영
# 23  2X16437  *시현
# 24  2X16678  *민지
# 25  2X14904  *지빈
# 26  2X13544  *다정
# 27  2X14844  *원선
# 28  2X15682  *보경
# 29  2X14559  *서현
# 30  1X15978  *승희
# 31  2X12342  *영은
# 32  2X12192  *예지
# 33  1X10418  *은서
# 34  1X16296  *진주
# 35  1X10833  *현민
# 36  2X13013  *주영
# 37  2X15028  *채현
# 38  2X10565  *민영
# 39  2X13592  *유빈
# 40  2X13686  *민지
# 41  2X12491  *윤서
# 42  2X16542  *하빈
# 43  2X11999  *윤아
# 44  2X13885  *유리

# %%
# 위아래로 붙이기, DF에 key값 추가
df = pd.concat([df1, df2], keys = (['데이터1', '데이터2']))
display(df)
# Out:
#               학번   이름
# 데이터1 0   1X10137  *현정
#      1   1X10194  *민지
#      2   1X12805  *예원
#      3   1X15363  *소연
#      4   1X16434  *민지
#      5   2X10333  *의정
#      6   2X10855  *서린
#      7   2X11621  *민서
#      8   2X11852  *채형
#      9   2X12158  *연우
#      10  2X12726  *희진
#      11  2X12795  *수아
#      12  2X13544  *다정
#      13  2X13847  *예린
#      14  2X14094  *민영
#      15  2X14235  *정연
#      16  2X14559  *서현
#      17  2X14839  *은진
#      18  2X14844  *원선
#      19  2X14900  *승연
#      20  2X14904  *지빈
#      21  2X15682  *보경
#      22  2X16030  *시영
#      23  2X16437  *시현
#      24  2X16678  *민지
# 데이터2 0   2X14904  *지빈
#      1   2X13544  *다정
#      2   2X14844  *원선
#      3   2X15682  *보경
#      4   2X14559  *서현
#      5   1X15978  *승희
#      6   2X12342  *영은
#      7   2X12192  *예지
#      8   1X10418  *은서
#      9   1X16296  *진주
#      10  1X10833  *현민
#      11  2X13013  *주영
#      12  2X15028  *채현
#      13  2X10565  *민영
#      14  2X13592  *유빈
#      15  2X13686  *민지
#      16  2X12491  *윤서
#      17  2X16542  *하빈
#      18  2X11999  *윤아
#      19  2X13885  *유리

# %%
# 위아래로 붙이기, 중복 삭제
df4 = pd.concat([df1, df2], keys = (['데이터1', '데이터2'])).drop_duplicates()
# df4.reset_index(inplace = True)   # 기존 index는 column으로 변경
df4.reset_index(drop = True, inplace = True)   # 기존 index 삭제
display(df4)
# Out:
#          학번   이름
# 0   1X10137  *현정
# 1   1X10194  *민지
# 2   1X12805  *예원
# 3   1X15363  *소연
# 4   1X16434  *민지
# 5   2X10333  *의정
# 6   2X10855  *서린
# 7   2X11621  *민서
# 8   2X11852  *채형
# 9   2X12158  *연우
# 10  2X12726  *희진
# 11  2X12795  *수아
# 12  2X13544  *다정
# 13  2X13847  *예린
# 14  2X14094  *민영
# 15  2X14235  *정연
# 16  2X14559  *서현
# 17  2X14839  *은진
# 18  2X14844  *원선
# 19  2X14900  *승연
# 20  2X14904  *지빈
# 21  2X15682  *보경
# 22  2X16030  *시영
# 23  2X16437  *시현
# 24  2X16678  *민지
# 25  1X15978  *승희
# 26  2X12342  *영은
# 27  2X12192  *예지
# 28  1X10418  *은서
# 29  1X16296  *진주
# 30  1X10833  *현민
# 31  2X13013  *주영
# 32  2X15028  *채현
# 33  2X10565  *민영
# 34  2X13592  *유빈
# 35  2X13686  *민지
# 36  2X12491  *윤서
# 37  2X16542  *하빈
# 38  2X11999  *윤아
# 39  2X13885  *유리

# %%
# 다른 변수가 있는 경우: 옵션이 없으면 모두 출력
df = pd.concat([df1, df3])
display(df)
# Out:
#          학번   이름 학과(전공)
# 0   1X10137  *현정    NaN
# 1   1X10194  *민지    NaN
# 2   1X12805  *예원    NaN
# 3   1X15363  *소연    NaN
# 4   1X16434  *민지    NaN
# ..      ...  ...    ...
# 35  2X12726  NaN   통계학과
# 36  1X15363  NaN   통계학과
# 37  2X12158  NaN   통계학과
# 38  2X16030  NaN   통계학과
# 39  2X13885  NaN   통계학과
#
# [65 rows x 3 columns]

# %%
# 모든 DF에 있는 변수만 출력
df = pd.concat([df1, df3], join = 'inner')
display(df)
# Out:
#          학번
# 0   1X10137
# 1   1X10194
# 2   1X12805
# 3   1X15363
# 4   1X16434
# ..      ...
# 35  2X12726
# 36  1X15363
# 37  2X12158
# 38  2X16030
# 39  2X13885
#
# [65 rows x 1 columns]

# %%
# pandas 2.0에서는 제거됨
df = df1.append(df2, sort = True)  # 변수명으로 정렬, 앞으로 삭제 예정
display(df)
# Out:
# C:\Users\SM-PC\AppData\Local\Temp\ipykernel_11308\3125223804.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df1.append(df2, sort = True)  # 변수명으로 정렬, 앞으로 삭제 예정
#      이름       학번
# 0   *현정  1X10137
# 1   *민지  1X10194
# 2   *예원  1X12805
# 3   *소연  1X15363
# 4   *민지  1X16434
# 5   *의정  2X10333
# 6   *서린  2X10855
# 7   *민서  2X11621
# 8   *채형  2X11852
# 9   *연우  2X12158
# 10  *희진  2X12726
# 11  *수아  2X12795
# 12  *다정  2X13544
# 13  *예린  2X13847
# 14  *민영  2X14094
# 15  *정연  2X14235
# 16  *서현  2X14559
# 17  *은진  2X14839
# 18  *원선  2X14844
# 19  *승연  2X14900
# 20  *지빈  2X14904
# 21  *보경  2X15682
# 22  *시영  2X16030
# 23  *시현  2X16437
# 24  *민지  2X16678
# 0   *지빈  2X14904
# 1   *다정  2X13544
# 2   *원선  2X14844
# 3   *보경  2X15682
# 4   *서현  2X14559
# 5   *승희  1X15978
# 6   *영은  2X12342
# 7   *예지  2X12192
# 8   *은서  1X10418
# 9   *진주  1X16296
# 10  *현민  1X10833
# 11  *주영  2X13013
# 12  *채현  2X15028
# 13  *민영  2X10565
# 14  *유빈  2X13592
# 15  *민지  2X13686
# 16  *윤서  2X12491
# 17  *하빈  2X16542
# 18  *윤아  2X11999
# 19  *유리  2X13885

# %%
# 죄우로 붙이기: side-by-side by specifying axis = 1
# DF+DF, DF+Series, Series+Series
# df4: df4.reset_index(drop=True, inplace=True) 적용한 DF
# 옵션이 없는 경우 index 기준으로 병합

# %%
# 동일 변수 확인 후 같은 자료만 좌우로 결합
df = pd.merge(df1, df2)
display(df)
# Out:
#         학번   이름
# 0  2X13544  *다정
# 1  2X14559  *서현
# 2  2X14844  *원선
# 3  2X14904  *지빈
# 4  2X15682  *보경

# %%
# 동일변수 확인 후 같은 자료만 좌우로 결합
df = pd.merge(df4, df3)
display(df)
# Out:
#          학번   이름        학과(전공)
# 0   1X10137  *현정          통계학과
# 1   1X10194  *민지     소프트웨어융합전공
# 2   1X12805  *예원          통계학과
# 3   1X15363  *소연          통계학과
# 4   1X16434  *민지        IT공학전공
# 5   2X10333  *의정       컴퓨터과학전공
# 6   2X10855  *서린          통계학과
# 7   2X11621  *민서          통계학과
# 8   2X11852  *채형          통계학과
# 9   2X12158  *연우          통계학과
# 10  2X12726  *희진          통계학과
# 11  2X12795  *수아          통계학과
# 12  2X13544  *다정          통계학과
# 13  2X13847  *예린          통계학과
# 14  2X14094  *민영          통계학과
# 15  2X14235  *정연          통계학과
# 16  2X14559  *서현          통계학과
# 17  2X14839  *은진          통계학과
# 18  2X14844  *원선          통계학과
# 19  2X14900  *승연          통계학과
# 20  2X14904  *지빈        IT공학전공
# 21  2X15682  *보경     소프트웨어융합전공
# 22  2X16030  *시영          통계학과
# 23  2X16437  *시현        IT공학전공
# 24  2X16678  *민지          통계학과
# 25  1X15978  *승희  르꼬르동블루외식경영전공
# 26  2X12342  *영은          통계학과
# 27  2X12192  *예지          통계학과
# 28  1X10418  *은서          통계학과
# 29  1X16296  *진주          통계학과
# 30  1X10833  *현민          경영학부
# 31  2X13013  *주영          통계학과
# 32  2X15028  *채현          통계학과
# 33  2X10565  *민영          통계학과
# 34  2X13592  *유빈          통계학과
# 35  2X13686  *민지          통계학과
# 36  2X12491  *윤서          통계학과
# 37  2X16542  *하빈          통계학과
# 38  2X11999  *윤아          경영학부
# 39  2X13885  *유리          통계학과

# %%
# 특정 변수 (column)값을 기준으로 좌우 결합
# 각 DF가 동일변수명을 가지는 경우 변수명에 suffixes가 붙음
## df = pd.merge(df1, df2, on = ['학번'], how = 'inner')  # intersection (default)
## df = pd.merge(df1, df2, on = ['학번'], suffixes = ['_l', '_r'], how = 'outer')  # union
## df = pd.merge(df1, df2, on = ['학번'], suffixes = ['_l', '_r'], how = 'left')   # union
## df = pd.merge(df1, df2, on = ['학번'], suffixes = ['_l', '_r'], how = 'right')   # union)
## df = pd.merge(df1, df2, on = ['학번'], suffixes = ['_l', '_r'], how = 'outer', indicator = True)   # 좌, 우, 좌우에 포함여부
## df = pd.merge(df1, df2, on = ['학번'], suffixes = ['_l', '_r'], how = 'outer', indicator = 'indicator_col')
df = pd.merge(df1, df2, suffixes = ['_l', '_r'], left_index=True, right_index=True)
display(df)
# Out:
#        학번_l 이름_l     학번_r 이름_r
# 0   1X10137  *현정  2X14904  *지빈
# 1   1X10194  *민지  2X13544  *다정
# 2   1X12805  *예원  2X14844  *원선
# 3   1X15363  *소연  2X15682  *보경
# 4   1X16434  *민지  2X14559  *서현
# 5   2X10333  *의정  1X15978  *승희
# 6   2X10855  *서린  2X12342  *영은
# 7   2X11621  *민서  2X12192  *예지
# 8   2X11852  *채형  1X10418  *은서
# 9   2X12158  *연우  1X16296  *진주
# 10  2X12726  *희진  1X10833  *현민
# 11  2X12795  *수아  2X13013  *주영
# 12  2X13544  *다정  2X15028  *채현
# 13  2X13847  *예린  2X10565  *민영
# 14  2X14094  *민영  2X13592  *유빈
# 15  2X14235  *정연  2X13686  *민지
# 16  2X14559  *서현  2X12491  *윤서
# 17  2X14839  *은진  2X16542  *하빈
# 18  2X14844  *원선  2X11999  *윤아
# 19  2X14900  *승연  2X13885  *유리

# %%
# 다른 변수명의 값을 기준으로 좌우 결합
df5 = df2.copy()
df5.rename(columns = {'학번':'ID'}, inplace = True)
df = pd.merge(df1, df5, left_on = '학번', right_on = 'ID', how = 'right')
display(df)
# Out:
#          학번 이름_x       ID 이름_y
# 0   2X14904  *지빈  2X14904  *지빈
# 1   2X13544  *다정  2X13544  *다정
# 2   2X14844  *원선  2X14844  *원선
# 3   2X15682  *보경  2X15682  *보경
# 4   2X14559  *서현  2X14559  *서현
# 5       NaN  NaN  1X15978  *승희
# 6       NaN  NaN  2X12342  *영은
# 7       NaN  NaN  2X12192  *예지
# 8       NaN  NaN  1X10418  *은서
# 9       NaN  NaN  1X16296  *진주
# 10      NaN  NaN  1X10833  *현민
# 11      NaN  NaN  2X13013  *주영
# 12      NaN  NaN  2X15028  *채현
# 13      NaN  NaN  2X10565  *민영
# 14      NaN  NaN  2X13592  *유빈
# 15      NaN  NaN  2X13686  *민지
# 16      NaN  NaN  2X12491  *윤서
# 17      NaN  NaN  2X16542  *하빈
# 18      NaN  NaN  2X11999  *윤아
# 19      NaN  NaN  2X13885  *유리

# %%
# 비교 변수명에 동일 값이 여러 개 있는 경우
df = pd.merge(df1, df2, on = ['이름'], how = 'inner')
display(df)
# Out:
#       학번_x   이름     학번_y
# 0  1X10194  *민지  2X13686
# 1  1X16434  *민지  2X13686
# 2  2X16678  *민지  2X13686
# 3  2X13544  *다정  2X13544
# 4  2X14094  *민영  2X10565
# 5  2X14559  *서현  2X14559
# 6  2X14844  *원선  2X14844
# 7  2X14904  *지빈  2X14904
# 8  2X15682  *보경  2X15682

# %% [markdown]
# ## Pyspark DataFrame

# %%
import pyspark
from pyspark.sql import SparkSession

스파크 = SparkSession.builder.appName('mergeDF').getOrCreate()
스파크.conf.set('spark.sql.execution.arrow.enabled', 'true')

# %%
스파크DF1 = 스파크.read.option('header', 'true').csv('hdfs://localhost:9000/Spark/combinedata/data1.csv')
스파크DF2 = 스파크.read.option('header', 'true').csv('hdfs://localhost:9000/Spark/combinedata/data2.csv')
스파크DF3 = 스파크.read.option('header', 'true').csv('hdfs://localhost:9000/Spark/combinedata/data3.csv')
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 스파크DF1 = 스파크.read.option('header', 'true').csv('hdfs://localhost:9000/Spark/combinedata/data1.csv')
#       2 스파크DF2 = 스파크.read.option('header', 'true').csv('hdfs://localhost:9000/Spark/combinedata/data2.csv')
#       3 스파크DF3 = 스파크.read.option('header', 'true').csv('hdfs://localhost:9000/Spark/combinedata/data3.csv')
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pyspark\sql\readwriter.py:410, in DataFrameReader.csv(self, path, schema, sep, encoding, quote, escape, comment, header, inferSchema, ignoreLeadingWhiteSpace, ignoreTrailingWhiteSpace, nullValue, nanValue, positiveInf, negativeInf, dateFormat, timestampFormat, maxColumns, maxCharsPerColumn, maxMalformedLogPerPartition, mode, columnNameOfCorruptRecord, multiLine, charToEscapeQuoteEscaping, samplingRatio, enforceSchema, emptyValue, locale, lineSep, pathGlobFilter, recursiveFileLookup, modifiedBefore, modifiedAfter, unescapedQuoteHandling)
#     408     path = [path]
#     409 if type(path) == list:
# --> 410     return self._df(self._jreader.csv(self._spark._sc._jvm.PythonUtils.toSeq(path)))
#     411 elif isinstance(path, RDD):
#     412     def func(iterator):
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\py4j\java_gateway.py:1321, in JavaMember.__call__(self, *args)
#    1315 command = proto.CALL_COMMAND_NAME +\
#    1316     self.command_header +\
#    1317     args_command +\
#    1318     proto.END_COMMAND_PART
#    1320 answer = self.gateway_client.send_command(command)
# -> 1321 return_value = get_return_value(
#    1322     answer, self.gateway_client, self.target_id, self.name)
#    1324 for temp_arg in temp_args:
#    1325     temp_arg._detach()
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pyspark\sql\utils.py:117, in capture_sql_exception.<locals>.deco(*a, **kw)
#     113 converted = convert_exception(e.java_exception)
#     114 if not isinstance(converted, UnknownException):
#     115     # Hide where the exception came from that shows a non-Pythonic
#     116     # JVM exception message.
# --> 117     raise converted from None
#     118 else:
#     119     raise
#
# AnalysisException: Path does not exist: hdfs://localhost:9000/Spark/combinedata/data1.csv

# %%
스파크DF1.show()
# 확ㅇ니 후 한글을 읽지 못하는 경우 위 프로그램에서 utf-8을 cp949로 변경

# %%
# 같은 columns
# 같은 것이 있어도 그대로 추가
DF = 스파크DF1.union(스파크DF2)
DF.show(30)

# %%
DF = 스파크DF1.unionAll(스파크DF2)
DF.show(30)

# %%
# 중복 삭제
DF = 스파크DF1.union(스파크DF2).distinct()
DF.show(30)

# %%
# PySpark
DF = 스파크DF2.unionByName(스파크DF3, allowMissingColumns = True)
DF.show(30)

# %%
# side-by-side (axis = 1)
# join
스파크DF1.join(스파크DF2).show()

# %%
DF = 스파크1.join(스파크DF3, 스파크DF1.학번 == 스파크DF3.학번)
# DF = 스파크1.join(스파크DF3, 스파크DF1.학번 == 스파크DF3.학번, 'inner')
# DF = 스파크1.join(스파크DF3, 스파크DF1.학번 == 스파크DF3.학번, 'outer')
# DF = 스파크1.join(스파크DF3, 스파크DF1.학번 == 스파크DF3.학번, 'left')
# DF = 스파크1.join(스파크DF3, 스파크DF1.학번 == 스파크DF3.학번, 'right')
DF.show()
