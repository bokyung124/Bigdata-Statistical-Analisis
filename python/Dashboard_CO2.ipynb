# %%
# !pip install hvplot panel
# Out:
# Requirement already satisfied: hvplot in /opt/homebrew/lib/python3.11/site-packages (0.8.3)
# Requirement already satisfied: panel in /opt/homebrew/lib/python3.11/site-packages (0.14.4)
# Requirement already satisfied: bokeh>=1.0.0 in /opt/homebrew/lib/python3.11/site-packages (from hvplot) (2.4.3)
# Requirement already satisfied: colorcet>=2 in /opt/homebrew/lib/python3.11/site-packages (from hvplot) (3.0.1)
# Requirement already satisfied: holoviews>=1.11.0 in /opt/homebrew/lib/python3.11/site-packages (from hvplot) (1.15.4)
# Requirement already satisfied: pandas in /opt/homebrew/lib/python3.11/site-packages (from hvplot) (1.5.3)
# Requirement already satisfied: numpy>=1.15 in /opt/homebrew/lib/python3.11/site-packages (from hvplot) (1.24.2)
# Requirement already satisfied: packaging in /opt/homebrew/lib/python3.11/site-packages (from hvplot) (23.0)
# Requirement already satisfied: param>=1.9.0 in /opt/homebrew/lib/python3.11/site-packages (from hvplot) (1.13.0)
# Requirement already satisfied: pyviz-comms>=0.7.4 in /opt/homebrew/lib/python3.11/site-packages (from panel) (2.2.1)
# Requirement already satisfied: markdown in /opt/homebrew/lib/python3.11/site-packages (from panel) (3.4.3)
# Requirement already satisfied: requests in /opt/homebrew/lib/python3.11/site-packages (from panel) (2.28.2)
# Requirement already satisfied: tqdm>=4.48.0 in /opt/homebrew/lib/python3.11/site-packages (from panel) (4.65.0)
# Requirement already satisfied: pyct>=0.4.4 in /opt/homebrew/lib/python3.11/site-packages (from panel) (0.5.0)
# Requirement already satisfied: bleach in /opt/homebrew/lib/python3.11/site-packages (from panel) (6.0.0)
# Requirement already satisfied: setuptools>=42 in /opt/homebrew/lib/python3.11/site-packages (from panel) (67.6.0)
# Requirement already satisfied: typing-extensions in /opt/homebrew/lib/python3.11/site-packages (from panel) (4.5.0)
# Requirement already satisfied: Jinja2>=2.9 in /opt/homebrew/lib/python3.11/site-packages (from bokeh>=1.0.0->hvplot) (3.1.2)
# Requirement already satisfied: pillow>=7.1.0 in /opt/homebrew/lib/python3.11/site-packages (from bokeh>=1.0.0->hvplot) (9.4.0)
# Requirement already satisfied: PyYAML>=3.10 in /opt/homebrew/lib/python3.11/site-packages (from bokeh>=1.0.0->hvplot) (6.0)
# Requirement already satisfied: tornado>=5.1 in /opt/homebrew/lib/python3.11/site-packages (from bokeh>=1.0.0->hvplot) (6.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /opt/homebrew/lib/python3.11/site-packages (from pandas->hvplot) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/lib/python3.11/site-packages (from pandas->hvplot) (2023.2)
# Requirement already satisfied: six>=1.9.0 in /opt/homebrew/lib/python3.11/site-packages (from bleach->panel) (1.16.0)
# Requirement already satisfied: webencodings in /opt/homebrew/lib/python3.11/site-packages (from bleach->panel) (0.5.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/homebrew/lib/python3.11/site-packages (from requests->panel) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/lib/python3.11/site-packages (from requests->panel) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/homebrew/lib/python3.11/site-packages (from requests->panel) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/lib/python3.11/site-packages (from requests->panel) (2022.12.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/homebrew/lib/python3.11/site-packages (from Jinja2>=2.9->bokeh>=1.0.0->hvplot) (2.1.2)

# %%
#!pip install pyparsing

# %%
import pandas as pd
import numpy as np
import panel as pn
import hvplot.pandas

# %%
, css_files=[pn.io.resources.CSS_URLS['font-awesome']]
# Out:
# "css_files=[pn.io.resources.CSS_URLS['font-awesome']]"

# %%
pn.extension("tabulator", css_files=[pn.io.resources.CSS_URLS['font-awesome']])
# Out:
# WARNING:param.panel_extension: A HoloViz extension was loaded previously. This means the extension is already initialized and custom css_files resources could not be loaded. If you are loading custom extensions with pn.extension(...) ensure that this is calledbefore any other HoloViz extension such as hvPlot or HoloViews.

# %%
df = pd.read_csv("owid-co2-data.csv")

# %%
df
# Out:
#            country  year iso_code  population           gdp  cement_co2  \
# 0      Afghanistan  1850      AFG   3752993.0           NaN         NaN
# 1      Afghanistan  1851      AFG   3769828.0           NaN         NaN
# 2      Afghanistan  1852      AFG   3787706.0           NaN         NaN
# 3      Afghanistan  1853      AFG   3806634.0           NaN         NaN
# 4      Afghanistan  1854      AFG   3825655.0           NaN         NaN
# ...            ...   ...      ...         ...           ...         ...
# 46518     Zimbabwe  2017      ZWE  14751101.0  2.194784e+10       0.469
# 46519     Zimbabwe  2018      ZWE  15052191.0  2.271535e+10       0.558
# 46520     Zimbabwe  2019      ZWE  15354606.0           NaN       0.570
# 46521     Zimbabwe  2020      ZWE  15669663.0           NaN       0.570
# 46522     Zimbabwe  2021      ZWE  15993525.0           NaN       0.570
#
#        cement_co2_per_capita     co2  co2_growth_abs  co2_growth_prct  ...  \
# 0                        NaN     NaN             NaN              NaN  ...
# 1                        NaN     NaN             NaN              NaN  ...
# 2                        NaN     NaN             NaN              NaN  ...
# 3                        NaN     NaN             NaN              NaN  ...
# 4                        NaN     NaN             NaN              NaN  ...
# ...                      ...     ...             ...              ...  ...
# 46518                  0.032   9.596          -0.937           -8.899  ...
# 46519                  0.037  11.795           2.199           22.920  ...
# 46520                  0.037  11.115          -0.681           -5.772  ...
# 46521                  0.036  10.608          -0.507           -4.559  ...
# 46522                  0.036  11.296           0.688            6.488  ...
#
#        share_global_cumulative_other_co2  share_global_flaring_co2  \
# 0                                    NaN                       NaN
# 1                                    NaN                       NaN
# 2                                    NaN                       NaN
# 3                                    NaN                       NaN
# 4                                    NaN                       NaN
# ...                                  ...                       ...
# 46518                                NaN                       0.0
# 46519                                NaN                       0.0
# 46520                                NaN                       0.0
# 46521                                NaN                       0.0
# 46522                                NaN                       0.0
#
#        share_global_gas_co2  share_global_luc_co2  share_global_oil_co2  \
# 0                       NaN                 0.121                   NaN
# 1                       NaN                 0.118                   NaN
# 2                       NaN                 0.116                   NaN
# 3                       NaN                 0.115                   NaN
# 4                       NaN                 0.114                   NaN
# ...                     ...                   ...                   ...
# 46518                   0.0                 0.219                 0.026
# 46519                   0.0                 0.211                 0.033
# 46520                   0.0                 0.183                 0.030
# 46521                   0.0                 0.194                 0.030
# 46522                   0.0                 0.190                 0.030
#
#        share_global_other_co2  total_ghg  total_ghg_excluding_lucf  trade_co2  \
# 0                         NaN        NaN                       NaN        NaN
# 1                         NaN        NaN                       NaN        NaN
# 2                         NaN        NaN                       NaN        NaN
# 3                         NaN        NaN                       NaN        NaN
# 4                         NaN        NaN                       NaN        NaN
# ...                       ...        ...                       ...        ...
# 46518                     NaN     115.59                     28.30      0.910
# 46519                     NaN     118.22                     30.83      0.771
# 46520                     NaN     117.96                     30.53      0.978
# 46521                     NaN        NaN                       NaN      1.006
# 46522                     NaN        NaN                       NaN        NaN
#
#        trade_co2_share
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# ...                ...
# 46518            9.486
# 46519            6.537
# 46520            8.795
# 46521            9.481
# 46522              NaN
#
# [46523 rows x 74 columns]

# %%
df.columns
# Out:
# Index(['country', 'year', 'iso_code', 'population', 'gdp', 'cement_co2',
#        'cement_co2_per_capita', 'co2', 'co2_growth_abs', 'co2_growth_prct',
#        'co2_including_luc', 'co2_including_luc_growth_abs',
#        'co2_including_luc_growth_prct', 'co2_including_luc_per_capita',
#        'co2_including_luc_per_gdp', 'co2_including_luc_per_unit_energy',
#        'co2_per_capita', 'co2_per_gdp', 'co2_per_unit_energy', 'coal_co2',
#        'coal_co2_per_capita', 'consumption_co2', 'consumption_co2_per_capita',
#        'consumption_co2_per_gdp', 'cumulative_cement_co2', 'cumulative_co2',
#        'cumulative_co2_including_luc', 'cumulative_coal_co2',
#        'cumulative_flaring_co2', 'cumulative_gas_co2', 'cumulative_luc_co2',
#        'cumulative_oil_co2', 'cumulative_other_co2', 'energy_per_capita',
#        'energy_per_gdp', 'flaring_co2', 'flaring_co2_per_capita', 'gas_co2',
#        'gas_co2_per_capita', 'ghg_excluding_lucf_per_capita', 'ghg_per_capita',
#        'land_use_change_co2', 'land_use_change_co2_per_capita', 'methane',
#        'methane_per_capita', 'nitrous_oxide', 'nitrous_oxide_per_capita',
#        'oil_co2', 'oil_co2_per_capita', 'other_co2_per_capita',
#        'other_industry_co2', 'primary_energy_consumption',
#        'share_global_cement_co2', 'share_global_co2',
#        'share_global_co2_including_luc', 'share_global_coal_co2',
#        'share_global_cumulative_cement_co2', 'share_global_cumulative_co2',
#        'share_global_cumulative_co2_including_luc',
#        'share_global_cumulative_coal_co2',
#        'share_global_cumulative_flaring_co2',
#        'share_global_cumulative_gas_co2', 'share_global_cumulative_luc_co2',
#        'share_global_cumulative_oil_co2', 'share_global_cumulative_other_co2',
#        'share_global_flaring_co2', 'share_global_gas_co2',
#        'share_global_luc_co2', 'share_global_oil_co2',
#        'share_global_other_co2', 'total_ghg', 'total_ghg_excluding_lucf',
#        'trade_co2', 'trade_co2_share'],
#       dtype='object')

# %%
df[df['country']=='World']
# Out:
#       country  year iso_code    population           gdp  cement_co2  \
# 45735   World  1750      NaN  7.456645e+08           NaN         NaN
# 45736   World  1751      NaN           NaN           NaN         NaN
# 45737   World  1752      NaN           NaN           NaN         NaN
# 45738   World  1753      NaN           NaN           NaN         NaN
# 45739   World  1754      NaN           NaN           NaN         NaN
# ...       ...   ...      ...           ...           ...         ...
# 46002   World  2017      NaN  7.599822e+09  1.104307e+14    1507.923
# 46003   World  2018      NaN  7.683790e+09  1.136302e+14    1569.218
# 46004   World  2019      NaN  7.764951e+09           NaN    1617.507
# 46005   World  2020      NaN  7.840953e+09           NaN    1637.537
# 46006   World  2021      NaN  7.909295e+09           NaN    1672.592
#
#        cement_co2_per_capita        co2  co2_growth_abs  co2_growth_prct  ...  \
# 45735                    NaN      9.351             NaN              NaN  ...
# 45736                    NaN      9.351           0.000            0.000  ...
# 45737                    NaN      9.354           0.004            0.039  ...
# 45738                    NaN      9.354           0.000            0.000  ...
# 45739                    NaN      9.358           0.004            0.039  ...
# ...                      ...        ...             ...              ...  ...
# 46002                  0.198  36096.738         572.547            1.612  ...
# 46003                  0.204  36826.508         729.772            2.022  ...
# 46004                  0.208  37082.559         256.049            0.695  ...
# 46005                  0.209  35264.086       -1818.472           -4.904  ...
# 46006                  0.211  37123.852        1859.764            5.274  ...
#
#        share_global_cumulative_other_co2  share_global_flaring_co2  \
# 45735                                NaN                       NaN
# 45736                                NaN                       NaN
# 45737                                NaN                       NaN
# 45738                                NaN                       NaN
# 45739                                NaN                       NaN
# ...                                  ...                       ...
# 46002                              100.0                     100.0
# 46003                              100.0                     100.0
# 46004                              100.0                     100.0
# 46005                              100.0                     100.0
# 46006                              100.0                     100.0
#
#        share_global_gas_co2  share_global_luc_co2  share_global_oil_co2  \
# 45735                   NaN                   NaN                   NaN
# 45736                   NaN                   NaN                   NaN
# 45737                   NaN                   NaN                   NaN
# 45738                   NaN                   NaN                   NaN
# 45739                   NaN                   NaN                   NaN
# ...                     ...                   ...                   ...
# 46002                 100.0                 100.0                 100.0
# 46003                 100.0                 100.0                 100.0
# 46004                 100.0                 100.0                 100.0
# 46005                 100.0                 100.0                 100.0
# 46006                 100.0                 100.0                 100.0
#
#        share_global_other_co2  total_ghg  total_ghg_excluding_lucf  trade_co2  \
# 45735                     NaN        NaN                       NaN        NaN
# 45736                     NaN        NaN                       NaN        NaN
# 45737                     NaN        NaN                       NaN        NaN
# 45738                     NaN        NaN                       NaN        NaN
# 45739                     NaN        NaN                       NaN        NaN
# ...                       ...        ...                       ...        ...
# 46002                   100.0  48251.879                 47031.820      0.000
# 46003                   100.0  49368.039                 47980.469     -0.004
# 46004                   100.0  49758.230                 48116.559      0.000
# 46005                   100.0        NaN                       NaN      0.000
# 46006                   100.0        NaN                       NaN      0.000
#
#        trade_co2_share
# 45735              NaN
# 45736              NaN
# 45737              NaN
# 45738              NaN
# 45739              NaN
# ...                ...
# 46002              0.0
# 46003             -0.0
# 46004              0.0
# 46005              0.0
# 46006              0.0
#
# [272 rows x 74 columns]

# %%
df[df['country']=='South Korea']
# Out:
#            country  year iso_code  population           gdp  cement_co2  \
# 39089  South Korea  1850      KOR   9548156.0           NaN         NaN
# 39090  South Korea  1851      KOR   9546011.0           NaN         NaN
# 39091  South Korea  1852      KOR   9544903.0           NaN         NaN
# 39092  South Korea  1853      KOR   9544833.0           NaN         NaN
# 39093  South Korea  1854      KOR   9544751.0           NaN         NaN
# ...            ...   ...      ...         ...           ...         ...
# 39256  South Korea  2017      KOR  51511640.0  1.907556e+12      26.351
# 39257  South Korea  2018      KOR  51676900.0  1.958392e+12      24.702
# 39258  South Korea  2019      KOR  51803832.0           NaN      24.930
# 39259  South Korea  2020      KOR  51844688.0           NaN      22.866
# 39260  South Korea  2021      KOR  51830136.0           NaN      23.704
#
#        cement_co2_per_capita      co2  co2_growth_abs  co2_growth_prct  ...  \
# 39089                    NaN      NaN             NaN              NaN  ...
# 39090                    NaN      NaN             NaN              NaN  ...
# 39091                    NaN      NaN             NaN              NaN  ...
# 39092                    NaN      NaN             NaN              NaN  ...
# 39093                    NaN      NaN             NaN              NaN  ...
# ...                      ...      ...             ...              ...  ...
# 39256                  0.512  654.537          16.623            2.606  ...
# 39257                  0.478  670.169          15.631            2.388  ...
# 39258                  0.481  646.102         -24.066           -3.591  ...
# 39259                  0.441  597.634         -48.468           -7.502  ...
# 39260                  0.457  616.075          18.441            3.086  ...
#
#        share_global_cumulative_other_co2  share_global_flaring_co2  \
# 39089                                NaN                       NaN
# 39090                                NaN                       NaN
# 39091                                NaN                       NaN
# 39092                                NaN                       NaN
# 39093                                NaN                       NaN
# ...                                  ...                       ...
# 39256                              2.023                     0.000
# 39257                              2.071                     0.000
# 39258                              2.113                     0.000
# 39259                              2.155                     0.000
# 39260                              2.194                     0.001
#
#        share_global_gas_co2  share_global_luc_co2  share_global_oil_co2  \
# 39089                   NaN                 0.131                   NaN
# 39090                   NaN                 0.122                   NaN
# 39091                   NaN                 0.115                   NaN
# 39092                   NaN                 0.110                   NaN
# 39093                   NaN                 0.104                   NaN
# ...                     ...                   ...                   ...
# 39256                 1.412                -0.137                 1.465
# 39257                 1.556                -0.141                 1.448
# 39258                 1.485                -0.136                 1.424
# 39259                 1.544                -0.156                 1.475
# 39260                 1.601                -0.164                 1.449
#
#        share_global_other_co2  total_ghg  total_ghg_excluding_lucf  trade_co2  \
# 39089                     NaN        NaN                       NaN        NaN
# 39090                     NaN        NaN                       NaN        NaN
# 39091                     NaN        NaN                       NaN        NaN
# 39092                     NaN        NaN                       NaN        NaN
# 39093                     NaN        NaN                       NaN        NaN
# ...                       ...        ...                       ...        ...
# 39256                   3.389     662.63                    708.43     35.766
# 39257                   3.410     669.70                    715.50     52.522
# 39258                   3.321     652.66                    698.46     61.326
# 39259                   3.437        NaN                       NaN     61.863
# 39260                   3.438        NaN                       NaN        NaN
#
#        trade_co2_share
# 39089              NaN
# 39090              NaN
# 39091              NaN
# 39092              NaN
# 39093              NaN
# ...                ...
# 39256            5.464
# 39257            7.837
# 39258            9.492
# 39259           10.351
# 39260              NaN
#
# [172 rows x 74 columns]

# %% [markdown]
# ## 대시보드 만들기
#
# ### 형태
# 연도에 따라 이산화탄소(CO2) 총배출량과 1인당 이산화탄소 배출량 관련 정보 보여줌
#
# ### 출력 콘텐츠
# - 연도에 따른 대륙별 이산화탄소 총배출량과 1인당 배출량 추이
# - 연도에 따른 대륙별 이산화탄소 배출량 표
# - 연도에 따른 국가별 이산화탄소 배출량과 국가 GDP 관계
# - 연도에 따른 대륙별 이산화탄소 배출랴의 소스 비교

# %%
df.rename(columns = {'co2' : 'CO2', 'co2_per_capita':'인당CO2', 'country':'국가', 'year':'연도'}, inplace = True)
df.rename(columns = {'coal_co2':'석탄', 'oil_co2':'석유','gas_co2':'가스'}, inplace = True)

# %%
# Fill NAs with 0s and create GDP per capita colulmn
df = df.fillna(0)
df['인당GDP'] = np.where(df['population'] != 0, df['gdp']/df['population'], 0)

# %%
df
# Out:
#                 국가    연도 iso_code  population           gdp  cement_co2  \
# 0      Afghanistan  1850      AFG   3752993.0  0.000000e+00       0.000
# 1      Afghanistan  1851      AFG   3769828.0  0.000000e+00       0.000
# 2      Afghanistan  1852      AFG   3787706.0  0.000000e+00       0.000
# 3      Afghanistan  1853      AFG   3806634.0  0.000000e+00       0.000
# 4      Afghanistan  1854      AFG   3825655.0  0.000000e+00       0.000
# ...            ...   ...      ...         ...           ...         ...
# 46518     Zimbabwe  2017      ZWE  14751101.0  2.194784e+10       0.469
# 46519     Zimbabwe  2018      ZWE  15052191.0  2.271535e+10       0.558
# 46520     Zimbabwe  2019      ZWE  15354606.0  0.000000e+00       0.570
# 46521     Zimbabwe  2020      ZWE  15669663.0  0.000000e+00       0.570
# 46522     Zimbabwe  2021      ZWE  15993525.0  0.000000e+00       0.570
#
#        cement_co2_per_capita     CO2  co2_growth_abs  co2_growth_prct  ...  \
# 0                      0.000   0.000           0.000            0.000  ...
# 1                      0.000   0.000           0.000            0.000  ...
# 2                      0.000   0.000           0.000            0.000  ...
# 3                      0.000   0.000           0.000            0.000  ...
# 4                      0.000   0.000           0.000            0.000  ...
# ...                      ...     ...             ...              ...  ...
# 46518                  0.032   9.596          -0.937           -8.899  ...
# 46519                  0.037  11.795           2.199           22.920  ...
# 46520                  0.037  11.115          -0.681           -5.772  ...
# 46521                  0.036  10.608          -0.507           -4.559  ...
# 46522                  0.036  11.296           0.688            6.488  ...
#
#        share_global_flaring_co2  share_global_gas_co2  share_global_luc_co2  \
# 0                           0.0                   0.0                 0.121
# 1                           0.0                   0.0                 0.118
# 2                           0.0                   0.0                 0.116
# 3                           0.0                   0.0                 0.115
# 4                           0.0                   0.0                 0.114
# ...                         ...                   ...                   ...
# 46518                       0.0                   0.0                 0.219
# 46519                       0.0                   0.0                 0.211
# 46520                       0.0                   0.0                 0.183
# 46521                       0.0                   0.0                 0.194
# 46522                       0.0                   0.0                 0.190
#
#        share_global_oil_co2  share_global_other_co2  total_ghg  \
# 0                     0.000                     0.0       0.00
# 1                     0.000                     0.0       0.00
# 2                     0.000                     0.0       0.00
# 3                     0.000                     0.0       0.00
# 4                     0.000                     0.0       0.00
# ...                     ...                     ...        ...
# 46518                 0.026                     0.0     115.59
# 46519                 0.033                     0.0     118.22
# 46520                 0.030                     0.0     117.96
# 46521                 0.030                     0.0       0.00
# 46522                 0.030                     0.0       0.00
#
#        total_ghg_excluding_lucf  trade_co2  trade_co2_share        인당GDP
# 0                          0.00      0.000            0.000     0.000000
# 1                          0.00      0.000            0.000     0.000000
# 2                          0.00      0.000            0.000     0.000000
# 3                          0.00      0.000            0.000     0.000000
# 4                          0.00      0.000            0.000     0.000000
# ...                         ...        ...              ...          ...
# 46518                     28.30      0.910            9.486  1487.877848
# 46519                     30.83      0.771            6.537  1509.106089
# 46520                     30.53      0.978            8.795     0.000000
# 46521                      0.00      1.006            9.481     0.000000
# 46522                      0.00      0.000            0.000     0.000000
#
# [46523 rows x 75 columns]

# %%
# !pip install holoviews
# Out:
# Requirement already satisfied: holoviews in /opt/homebrew/lib/python3.11/site-packages (1.15.4)
# Requirement already satisfied: param<2.0,>=1.9.3 in /opt/homebrew/lib/python3.11/site-packages (from holoviews) (1.13.0)
# Requirement already satisfied: numpy>=1.0 in /opt/homebrew/lib/python3.11/site-packages (from holoviews) (1.24.2)
# Requirement already satisfied: pyviz-comms>=0.7.4 in /opt/homebrew/lib/python3.11/site-packages (from holoviews) (2.2.1)
# Requirement already satisfied: panel>=0.13.1 in /opt/homebrew/lib/python3.11/site-packages (from holoviews) (0.14.4)
# Requirement already satisfied: colorcet in /opt/homebrew/lib/python3.11/site-packages (from holoviews) (3.0.1)
# Requirement already satisfied: packaging in /opt/homebrew/lib/python3.11/site-packages (from holoviews) (23.0)
# Requirement already satisfied: pandas>=0.20.0 in /opt/homebrew/lib/python3.11/site-packages (from holoviews) (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /opt/homebrew/lib/python3.11/site-packages (from pandas>=0.20.0->holoviews) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/lib/python3.11/site-packages (from pandas>=0.20.0->holoviews) (2023.2)
# Requirement already satisfied: bokeh<2.5.0,>=2.4.0 in /opt/homebrew/lib/python3.11/site-packages (from panel>=0.13.1->holoviews) (2.4.3)
# Requirement already satisfied: markdown in /opt/homebrew/lib/python3.11/site-packages (from panel>=0.13.1->holoviews) (3.4.3)
# Requirement already satisfied: requests in /opt/homebrew/lib/python3.11/site-packages (from panel>=0.13.1->holoviews) (2.28.2)
# Requirement already satisfied: tqdm>=4.48.0 in /opt/homebrew/lib/python3.11/site-packages (from panel>=0.13.1->holoviews) (4.65.0)
# Requirement already satisfied: pyct>=0.4.4 in /opt/homebrew/lib/python3.11/site-packages (from panel>=0.13.1->holoviews) (0.5.0)
# Requirement already satisfied: bleach in /opt/homebrew/lib/python3.11/site-packages (from panel>=0.13.1->holoviews) (6.0.0)
# Requirement already satisfied: setuptools>=42 in /opt/homebrew/lib/python3.11/site-packages (from panel>=0.13.1->holoviews) (67.6.0)
# Requirement already satisfied: typing-extensions in /opt/homebrew/lib/python3.11/site-packages (from panel>=0.13.1->holoviews) (4.5.0)
# Requirement already satisfied: Jinja2>=2.9 in /opt/homebrew/lib/python3.11/site-packages (from bokeh<2.5.0,>=2.4.0->panel>=0.13.1->holoviews) (3.1.2)
# Requirement already satisfied: pillow>=7.1.0 in /opt/homebrew/lib/python3.11/site-packages (from bokeh<2.5.0,>=2.4.0->panel>=0.13.1->holoviews) (9.4.0)
# Requirement already satisfied: PyYAML>=3.10 in /opt/homebrew/lib/python3.11/site-packages (from bokeh<2.5.0,>=2.4.0->panel>=0.13.1->holoviews) (6.0)
# Requirement already satisfied: tornado>=5.1 in /opt/homebrew/lib/python3.11/site-packages (from bokeh<2.5.0,>=2.4.0->panel>=0.13.1->holoviews) (6.2)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/lib/python3.11/site-packages (from python-dateutil>=2.8.1->pandas>=0.20.0->holoviews) (1.16.0)
# Requirement already satisfied: webencodings in /opt/homebrew/lib/python3.11/site-packages (from bleach->panel>=0.13.1->holoviews) (0.5.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/homebrew/lib/python3.11/site-packages (from requests->panel>=0.13.1->holoviews) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/lib/python3.11/site-packages (from requests->panel>=0.13.1->holoviews) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/homebrew/lib/python3.11/site-packages (from requests->panel>=0.13.1->holoviews) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/lib/python3.11/site-packages (from requests->panel>=0.13.1->holoviews) (2022.12.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/homebrew/lib/python3.11/site-packages (from Jinja2>=2.9->bokeh<2.5.0,>=2.4.0->panel>=0.13.1->holoviews) (2.1.2)

# %%
# !pip install bokeh==2.4.3
# Out:
# Collecting bokeh==2.4.3
#   Using cached bokeh-2.4.3-py3-none-any.whl (18.5 MB)
# Requirement already satisfied: Jinja2>=2.9 in /opt/homebrew/lib/python3.11/site-packages (from bokeh==2.4.3) (3.1.2)
# Requirement already satisfied: numpy>=1.11.3 in /opt/homebrew/lib/python3.11/site-packages (from bokeh==2.4.3) (1.24.2)
# Requirement already satisfied: packaging>=16.8 in /opt/homebrew/lib/python3.11/site-packages (from bokeh==2.4.3) (23.0)
# Requirement already satisfied: pillow>=7.1.0 in /opt/homebrew/lib/python3.11/site-packages (from bokeh==2.4.3) (9.4.0)
# Requirement already satisfied: PyYAML>=3.10 in /opt/homebrew/lib/python3.11/site-packages (from bokeh==2.4.3) (6.0)
# Requirement already satisfied: tornado>=5.1 in /opt/homebrew/lib/python3.11/site-packages (from bokeh==2.4.3) (6.2)
# Requirement already satisfied: typing-extensions>=3.10.0 in /opt/homebrew/lib/python3.11/site-packages (from bokeh==2.4.3) (4.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/homebrew/lib/python3.11/site-packages (from Jinja2>=2.9->bokeh==2.4.3) (2.1.2)
# Installing collected packages: bokeh
#   Attempting uninstall: bokeh
#     Found existing installation: bokeh 3.1.0
#     Uninstalling bokeh-3.1.0:
#       Successfully uninstalled bokeh-3.1.0
# Successfully installed bokeh-2.4.3

# %%
# Make DataFrame Pipeline Interactive
idf = df.interactive()

# %%
idf
# Out:
# <div id='1083'>
#   <div class="bk-root" id="adc03814-790f-480c-ae53-53f3d99aad62" data-root-id="1083"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"27d53f31-63dd-4b48-a0b3-130120b99c5d":{"defs":[{"extends":null,"module":null,"name":"ReactiveHTML1","overrides":[],"properties":[]},{"extends":null,"module":null,"name":"FlexBox1","overrides":[],"properties":[{"default":"flex-start","kind":null,"name":"align_content"},{"default":"flex-start","kind":null,"name":"align_items"},{"default":"row","kind":null,"name":"flex_direction"},{"default":"wrap","kind":null,"name":"flex_wrap"},{"default":"flex-start","kind":null,"name":"justify_content"}]},{"extends":null,"module":null,"name":"GridStack1","overrides":[],"properties":[{"default":"warn","kind":null,"name":"mode"},{"default":null,"kind":null,"name":"ncols"},{"default":null,"kind":null,"name":"nrows"},{"default":true,"kind":null,"name":"allow_resize"},{"default":true,"kind":null,"name":"allow_drag"},{"default":[],"kind":null,"name":"state"}]},{"extends":null,"module":null,"name":"click1","overrides":[],"properties":[{"default":"","kind":null,"name":"terminal_output"},{"default":"","kind":null,"name":"debug_name"},{"default":0,"kind":null,"name":"clears"}]},{"extends":null,"module":null,"name":"NotificationAreaBase1","overrides":[],"properties":[{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"}]},{"extends":null,"module":null,"name":"NotificationArea1","overrides":[],"properties":[{"default":[],"kind":null,"name":"notifications"},{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"},{"default":[{"background":"#ffc107","icon":{"className":"fas fa-exclamation-triangle","color":"white","tagName":"i"},"type":"warning"},{"background":"#007bff","icon":{"className":"fas fa-info-circle","color":"white","tagName":"i"},"type":"info"}],"kind":null,"name":"types"}]},{"extends":null,"module":null,"name":"Notification","overrides":[],"properties":[{"default":null,"kind":null,"name":"background"},{"default":3000,"kind":null,"name":"duration"},{"default":null,"kind":null,"name":"icon"},{"default":"","kind":null,"name":"message"},{"default":null,"kind":null,"name":"notification_type"},{"default":false,"kind":null,"name":"_destroyed"}]},{"extends":null,"module":null,"name":"TemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]},{"extends":null,"module":null,"name":"MaterialTemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]}],"roots":{"references":[{"attributes":{"children":[{"id":"1089"},{"id":"1090"}],"margin":[0,0,0,0],"name":"Column02369"},"id":"1088","type":"Column"},{"attributes":{"children":[{"id":"1085"},{"id":"1088"}],"margin":[0,0,0,0],"name":"Column02376"},"id":"1084","type":"Column"},{"attributes":{"children":[{"id":"1084"}],"margin":[0,0,0,0],"name":"Row02377"},"id":"1083","type":"Row"},{"attributes":{"client_comm_id":"3646f6b1e6574c818f1c4fe202aaf311","comm_id":"35b1cebf74834558aed316c9ff15ffd3","plot_id":"1083"},"id":"1092","type":"panel.models.comm_manager.CommManager"},{"attributes":{"margin":[0,0,0,0],"name":"Column02367"},"id":"1086","type":"Column"},{"attributes":{"margin":[0,0,0,0],"name":"Column02373"},"id":"1089","type":"Column"},{"attributes":{"margin":[5,5,5,5],"name":"DataFrame02370","text":"&lt;table class=&quot;dataframe panel-df&quot;&gt;\n  &lt;thead&gt;\n    &lt;tr style=&quot;text-align: right;&quot;&gt;\n      &lt;th&gt;&lt;/th&gt;\n      &lt;th&gt;\uad6d\uac00&lt;/th&gt;\n      &lt;th&gt;\uc5f0\ub3c4&lt;/th&gt;\n      &lt;th&gt;iso_code&lt;/th&gt;\n      &lt;th&gt;population&lt;/th&gt;\n      &lt;th&gt;gdp&lt;/th&gt;\n      &lt;th&gt;cement_co2&lt;/th&gt;\n      &lt;th&gt;cement_co2_per_capita&lt;/th&gt;\n      &lt;th&gt;CO2&lt;/th&gt;\n      &lt;th&gt;co2_growth_abs&lt;/th&gt;\n      &lt;th&gt;co2_growth_prct&lt;/th&gt;\n      &lt;th&gt;co2_including_luc&lt;/th&gt;\n      &lt;th&gt;co2_including_luc_growth_abs&lt;/th&gt;\n       ...

# %%
idf.columns
# Out:
# <div id='1093'>
#   <div class="bk-root" id="03e9395f-19e8-48bd-900e-68c91150b5c8" data-root-id="1093"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"0ec6b064-172c-47b4-9898-aebdd4234b8d":{"defs":[{"extends":null,"module":null,"name":"ReactiveHTML1","overrides":[],"properties":[]},{"extends":null,"module":null,"name":"FlexBox1","overrides":[],"properties":[{"default":"flex-start","kind":null,"name":"align_content"},{"default":"flex-start","kind":null,"name":"align_items"},{"default":"row","kind":null,"name":"flex_direction"},{"default":"wrap","kind":null,"name":"flex_wrap"},{"default":"flex-start","kind":null,"name":"justify_content"}]},{"extends":null,"module":null,"name":"GridStack1","overrides":[],"properties":[{"default":"warn","kind":null,"name":"mode"},{"default":null,"kind":null,"name":"ncols"},{"default":null,"kind":null,"name":"nrows"},{"default":true,"kind":null,"name":"allow_resize"},{"default":true,"kind":null,"name":"allow_drag"},{"default":[],"kind":null,"name":"state"}]},{"extends":null,"module":null,"name":"click1","overrides":[],"properties":[{"default":"","kind":null,"name":"terminal_output"},{"default":"","kind":null,"name":"debug_name"},{"default":0,"kind":null,"name":"clears"}]},{"extends":null,"module":null,"name":"NotificationAreaBase1","overrides":[],"properties":[{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"}]},{"extends":null,"module":null,"name":"NotificationArea1","overrides":[],"properties":[{"default":[],"kind":null,"name":"notifications"},{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"},{"default":[{"background":"#ffc107","icon":{"className":"fas fa-exclamation-triangle","color":"white","tagName":"i"},"type":"warning"},{"background":"#007bff","icon":{"className":"fas fa-info-circle","color":"white","tagName":"i"},"type":"info"}],"kind":null,"name":"types"}]},{"extends":null,"module":null,"name":"Notification","overrides":[],"properties":[{"default":null,"kind":null,"name":"background"},{"default":3000,"kind":null,"name":"duration"},{"default":null,"kind":null,"name":"icon"},{"default":"","kind":null,"name":"message"},{"default":null,"kind":null,"name":"notification_type"},{"default":false,"kind":null,"name":"_destroyed"}]},{"extends":null,"module":null,"name":"TemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]},{"extends":null,"module":null,"name":"MaterialTemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]}],"roots":{"references":[{"attributes":{"children":[{"id":"1094"}],"margin":[0,0,0,0],"name":"Row02469"},"id":"1093","type":"Row"},{"attributes":{"children":[{"id":"1095"},{"id":"1098"}],"margin":[0,0,0,0],"name":"Column02468"},"id":"1094","type":"Column"},{"attributes":{"children":[{"id":"1099"},{"id":"1100"}],"margin":[0,0,0,0],"name":"Column02461"},"id":"1098","type":"Column"},{"attributes":{"margin":[0,0,0,0],"name":"Column02465"},"id":"1099","type":"Column"},{"attributes":{"margin":[5,5,5,5],"name":"HSpacer02466","sizing_mode":"stretch_width"},"id":"1097","type":"Spacer"},{"attributes":{"client_comm_id":"f3b6bdc331f7477fb94b34b6a457d205","comm_id":"aa811845681b4e42bf8cda1e407e550f","plot_id":"1093"},"id":"1102","type":"panel.models.comm_manager.CommManager"},{"attributes":{"margin":[0,0,0,0],"name":"Column02459"},"id":"1096","type":"Column"},{"attributes":{"margin":[5,5,5,5],"name":"interactive02460","text":"&lt;pre&gt;Index([&#x27;\uad6d\uac00&#x27;, &#x27;\uc5f0\ub3c4&#x27;, &#x27;iso_code&#x27;, &#x27;population&#x27;, &#x27;gdp&#x27;, &#x27;cement_co2&#x27;,\n       &#x27;cement_co2_per_capita&#x27;, &#x27;CO2&#x27;, &#x27;co2_growth_abs&#x27;, &#x27;co2_growth_prct&#x27;,\n       &#x27;co2_including_luc&#x27;, &#x27;co2_including_luc_growth_abs&#x27;,\n       &#x27;co2_including_luc_growth_prct&#x27;, &#x27;co2_including_luc_per_capita&#x27;,\n       &#x27;co2_including_luc_per_gdp&#x27;, &#x27;co2_including_luc_per_unit_energy&#x27; ...
#     var render_items = [{"docid":"0ec6b064-172c-47b4-9898-aebdd4234b8d","root_ids":["1093"],"roots":{"1093":"03e9395f-19e8-48bd-900e-68c91150b5c8"}}];
#     root.Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   if (root.Bokeh !== undefined && root.Bokeh.Panel !== undefined && ( root['Tabulator'] !== undefined) && ( root['Tabulator'] !== undefined) && ( root['Tabulator'] !== undefined) && ( root['Tabulator'] !== undefined) && ( root['Tabulator'] !== undefined) && ( root['Tabulator'] !== undefined) && ( root['Tabulator'] !== undefined) && ( root['Tabulator'] !== undefined)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (root.Bokeh !== undefined && root.Bokeh.Panel !== undefined && (root['Tabulator'] !== undefined) && (root['Tabulator'] !== unde

# %% [markdown]
# ## CO2 emission over time by continent

# %%
# Define Panel Widgets
연도스라이더 = pn.widgets.IntSlider(name = '연도 스라이더', start = 1750, end = 2020)
연도스라이더

# %%
# Radio buttons for CO2 measure
Y축_co2 = pn.widgets.RadioButtonGroup(
    name = 'Y축', 
    options = ['CO2', '인당CO2'],
    button_type = 'success'
)

# %%
대륙 = ['World', 'Asia', 'Oceania', 'Europe', 'Africa', 'North America', 'South America']
Korea = ['South Korea', 'North Korea']

파이프라인_co2 = (
    idf[(idf.연도 <= 연도스라이더) & (idf.국가.isin(대륙))]
    .groupby(['국가', '연도'])[Y축_co2].mean()
    .to_frame()
    .reset_index()
    .sort_values(by='연도')
    .reset_index(drop=True)
)

# %%
파이프라인_co2

# %%
시계열그림_co2 = 파이프라인_co2.hvplot(x='연도', by='국가', y = Y축_co2, line_width = 3)
시계열그림_co2

# %% [markdown]
# ## Table - CO2 emission over time by continent

# %%
표_co2 = 파이프라인_co2.pipe(pn.widgets.Tabulator, pagination="remote", page_size=200, theme="fast", sizing_mode="stretch_both")
표_co2

# %% [markdown]
# ## CO2 vs GDP scatter plot

# %%
파이프라인_co2_vs_gdp = (
    idf[(idf.연도 == 연도스라이더) & (~(idf.국가.isin(대륙)))]
    .groupby(['국가', '연도', '인당GDP'])['인당CO2'].mean()
    .to_dataframe()
    .reset_index()
    .sort_values(by='연도')
    .reset_index(drop = True)
)

파이프라인_co2_vs_gdp

# %%
산점도_co2_vs_gdp = 파이프라인_co2_vs_gdp.hvplot(x='인당GDP', y='인당CO2', by='국가',
                                         size=80, kind='scatter', alpha=0.7)
산점도_co2_vs_gdp

# %% [markdown]
# ## Bar chart with CO2 sources by continent

# %%
Y축_co2_source = pn.widgets.RadioButtonGroup(
    name = 'Y축',
    options = ['석탄', '석유', '가스'],
    button_type = 'success'
)

세계제외 = ['Asia', 'Oceania', 'Europe', 'Africa', 'North America', 'South America']

파이프라인_co2_source = (
    idf[(idf.연도 == 연도스라이더) & (idf.국가.isin(세계제외))]
    .groupby(['국가', '연도'])[Y축_co2_source].sum()
    .to_frame()
    .reset_index()
    .sort_values(by='연도')
    .reset_index(drop=True)
)

# %%
막대그래프_co2_source = 파이프라인_co2_source.hvplot(kind='bar', x='국가', y=Y축_co2_source)
막대그래프_co2_source

# %% [markdown]
# ## Templates

# %% [markdown]
# FastListTemplate

# %%
CO2와기후변화 = '#### 이산화탄소 (CO2)는 기후 변화의 주요 원인 중 하나이다. CO2는'

template = pn.template.FastListTemplate(
    title = '세계 이산화탄소 배출 대시보드(World CO2 emission dashboard',
    sidebar = [pn.pane.Markdown("# 이산화탄소 배출과 기후변화"),
               pn.pane.Markdown(CO2와 기후변화),
               pn.pane.JPG('기후변화.jpg', sizing_mode='scale_both'),
               pn.pane.Markdown('## 연도 설정'),
               연도스라이더],
    main = [pn.Row(pn.Column(Y축_co2, 시계열그림_co2.panel(width=800), margin=(0,25)),
                             표_co2.panel(width=400)),
            pn.Row(pn.Column(산점도_co2_vs_gdp.panel(width=600), margin=(0,25)),
                   pn.Column(Y축_co2_source, 막대그래프_co2_source.panel(width=600)))]
    accent_base_color = '#88d8b0'
    header_backgruond = '#88d8b0'
)

template.servable();
